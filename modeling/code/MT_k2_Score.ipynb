# %%
import pandas as pd
import numpy as np
import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder

# %%
original_df = pd.read_excel('./main_df_dropna_completed.xlsx',index_col=0)

# %%
main_df = pd.get_dummies(original_df, columns=['주거래은행'])

# %%
main_df = main_df.reset_index()

# %%
# '산업위험_경기민감도' 컬럼 선택
categorical_data_2 = main_df[['산업위험_경기민감도']]

# OneHotEncoder 객체 생성 및 학습
ohe_2 = OneHotEncoder(sparse=False)
ohe_2.fit(categorical_data_2)

# One-Hot-Encoding 적용
ohe_encoded_2 = ohe_2.transform(categorical_data_2)

# 인코딩된 데이터를 DataFrame으로 변환
industry_encode = pd.DataFrame(ohe_encoded_2)

# 원본 DataFrame과 원핫 인코딩된 데이터를 합침
categorical_data = pd.concat([main_df, industry_encode], axis=1)

# %%
categorical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10900 entries, 0 to 10899
# Data columns (total 83 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                10900 non-null  int64
#  1   회사명                  10900 non-null  object
#  2   거래소코드                10900 non-null  int64
#  3   회계년도                 10900 non-null  int64
#  4   유동비율(%)              10900 non-null  float64
#  5   당좌비율(%)              10900 non-null  float64
#  6   비유동비율(%)             10900 non-null  float64
#  7   부채비율(%)              10900 non-null  float64
#  8   유동부채비율(%)            10900 non-null  float64
#  9   차입금의존도(%)            10900 non-null  float64
#  10  이익잉여금비율(%)           10900 non-null  float64
#  11  순운전자본비율(%)           10900 non-null  float64
#  12  비유동장기적합률(%)          10900 non-null  float64
#  13  이자보상배율(이자비용)(배)      10900 non-null  float64
#  14  외화포지션(배)             10900 non-null  float64
#  15  총자본순이익률(%)           10900 non-null  float64
#  16  자기자본순이익률(%)          10900 non-null  float64
#  17  경영자본순이익률(%)          10900 non-null  float64
#  18  매출액순이익률(%)           10900 non-null  float64
#  19  총자본정상영업이익률(%)        10900 non-null  float64
#  20  자기자본정상영업이익률(%)       10900 non-null  float64
#  21  매출액정상영업이익률(%)        10900 non-null  float64
#  22  금융비용부담률(%)           10900 non-null  float64
#  23  총자산회전율(배)            10900 non-null  float64
#  24  매출채권회전률(배)           10900 non-null  float64
#  25  당좌자산회전률(배)           10900 non-null  float64
#  26  재고자산회전률(배)           10900 non-null  float64
#  27  유형자산회전율(배)           10900 non-null  float64
#  28  매입채무회전률(배)           10900 non-null  float64
#  29  자기자본회전률(배)           10900 non-null  float64
#  30  경영자본회전률(배)           10900 non-null  float64
#  31  유동자산증가율(%)           10900 non-null  float64
#  32  매출액증가율(%)            10900 non-null  float64
#  33  정상영업이익증가율(%)         10900 non-null  float64
#  34  순이익증가율(%)            10900 non-null  float64
#  35  spread(%)            10900 non-null  float64
#  36  PPI(2015기준)          10900 non-null  float64
#  37  실질GDP성장률(%)          10900 non-null  float64
#  38  EV/EBITDA(배)         10900 non-null  float64
#  39  52주베타(배)             10900 non-null  float64
#  40  PER                  10900 non-null  float64
#  41  PBR                  10900 non-null  float64
#  42  PCR                  10900 non-null  float64
#  43  CASH FLOW 대 부채비율(%)  10900 non-null  float64
#  44  총자본투자효율(%)           10900 non-null  float64
#  45  log_평균총자산            10900 non-null  float64
#  46  매출액(수익)(천원)          10900 non-null  int64
#  47  K2_score             10900 non-null  float64
#  48  K2_부실판단              10900 non-null  object
#  49  산업위험_경기민감도           10900 non-null  object
#  50  최대주주특수관계인_지분율(%)     10900 non-null  float64
#  51  최대주주변경횟수(회)          10900 non-null  int64
#  52  감사법인변경횟수(회)          10900 non-null  int64
#  53  업력(년)                10900 non-null  int64
#  54  평균근속연수(년)            10900 non-null  float64
#  55  직원수증감율(%)            10900 non-null  float64
#  56  기간제비율(%)             10900 non-null  float64
#  57  R&D집중도(%)            10900 non-null  float64
#  58  수출기업여부(dummy)        10900 non-null  int64
#  59  Target               10900 non-null  int64
#  60  주거래은행_BNK경남은행        10900 non-null  bool
#  61  주거래은행_BNK부산은행        10900 non-null  bool
#  62  주거래은행_DGB대구은행        10900 non-null  bool
#  63  주거래은행_IBK기업은행        10900 non-null  bool
#  64  주거래은행_KDB산업은행        10900 non-null  bool
#  65  주거래은행_KEB하나은행        10900 non-null  bool
#  66  주거래은행_NH농협           10900 non-null  bool
#  67  주거래은행_SC제일은행         10900 non-null  bool
#  68  주거래은행_광주은행           10900 non-null  bool
#  69  주거래은행_국민은행           10900 non-null  bool
#  70  주거래은행_수협             10900 non-null  bool
#  71  주거래은행_시티은행           10900 non-null  bool
#  72  주거래은행_신한은행           10900 non-null  bool
#  73  주거래은행_우리은행           10900 non-null  bool
#  74  주거래은행_전북은행           10900 non-null  bool
#  75  주거래은행_한국수출입은행        10900 non-null  bool
#  76  주거래은행_한국스탠다드차타드은행    10900 non-null  bool
#  77  주거래은행_한국씨티은행         10900 non-null  bool
#  78  0                    10900 non-null  float64
#  79  1                    10900 non-null  float64
#  80  2                    10900 non-null  float64
#  81  3                    10900 non-null  float64
#  82  4                    10900 non-null  float64
# dtypes: bool(18), float64(53), int64(9), object(3)
# memory usage: 5.6+ MB

# %%
categorical_data.drop(labels=['index','산업위험_경기민감도','K2_부실판단','매출액(수익)(천원)'],axis=1,inplace=True)

# %%
categorical_data.columns
# Out:
# Index([                '회사명',               '거래소코드',                '회계년도',
#                    '유동비율(%)',             '당좌비율(%)',            '비유동비율(%)',
#                    '부채비율(%)',           '유동부채비율(%)',           '차입금의존도(%)',
#                 '이익잉여금비율(%)',          '순운전자본비율(%)',         '비유동장기적합률(%)',
#            '이자보상배율(이자비용)(배)',            '외화포지션(배)',          '총자본순이익률(%)',
#                '자기자본순이익률(%)',         '경영자본순이익률(%)',          '매출액순이익률(%)',
#              '총자본정상영업이익률(%)',      '자기자본정상영업이익률(%)',       '매출액정상영업이익률(%)',
#                 '금융비용부담률(%)',           '총자산회전율(배)',          '매출채권회전률(배)',
#                 '당좌자산회전률(배)',          '재고자산회전률(배)',          '유형자산회전율(배)',
#                 '매입채무회전률(배)',          '자기자본회전률(배)',          '경영자본회전률(배)',
#                 '유동자산증가율(%)',           '매출액증가율(%)',        '정상영업이익증가율(%)',
#                  '순이익증가율(%)',           'spread(%)',         'PPI(2015기준)',
#                '실질GDP성장률(%)',        'EV/EBITDA(배)',            '52주베타(배)',
#                        'PER',                 'PBR',                 'PCR',
#        'CASH FLOW 대 부채비율(%)',          '총자본투자효율(%)',           'log_평균총자산',
#                   'K2_score',    '최대주주특수관계인_지분율(%)',         '최대주주변경횟수(회)',
#                '감사법인변경횟수(회)',               '업력(년)',           '평균근속연수(년)',
#                  '직원수증감율(%)',            '기간제비율(%)',           'R&D집중도(%)',
#              '수출기업여부(dummy)',              'Target',       '주거래은행_BNK경남은행',
#              '주거래은행_BNK부산은행',       '주거래은행_DGB대구은행',       '주거래은행_IBK기업은행',
#              '주거래은행_KDB산업은행',       '주거래은행_KEB하나은행',          '주거래은행_NH농협',
#               '주거래은행_SC제일은행',          '주거래은행_광주은행',          '주거래은행_국민은행',
#                   '주거래은행_수협',          '주거래은행_시티은행',          '주거래은행_신한은행',
#                 '주거래은행_우리은행',          '주거래은행_전북은행',       '주거래은행_한국수출입은행',
#          '주거래은행_한국스탠다드차타드은행',        '주거래은행_한국씨티은행',                     0,
#                            1,                     2,                     3,
#                            4],
#       dtype='object')

# %%
categorical_data.columns =[                '회사명',               '거래소코드',                '회계년도',
                   '유동비율(%)',             '당좌비율(%)',            '비유동비율(%)',
                   '부채비율(%)',           '유동부채비율(%)',           '차입금의존도(%)',
                '이익잉여금비율(%)',          '순운전자본비율(%)',         '비유동장기적합률(%)',
           '이자보상배율(이자비용)(배)',            '외화포지션(배)',          '총자본순이익률(%)',
               '자기자본순이익률(%)',         '경영자본순이익률(%)',          '매출액순이익률(%)',
             '총자본정상영업이익률(%)',      '자기자본정상영업이익률(%)',       '매출액정상영업이익률(%)',
                '금융비용부담률(%)',           '총자산회전율(배)',          '매출채권회전률(배)',
                '당좌자산회전률(배)',          '재고자산회전률(배)',          '유형자산회전율(배)',
                '매입채무회전률(배)',          '자기자본회전률(배)',          '경영자본회전률(배)',
                '유동자산증가율(%)',           '매출액증가율(%)',        '정상영업이익증가율(%)',
                 '순이익증가율(%)',           'spread(%)',         'PPI(2015기준)',
               '실질GDP성장률(%)',        'EV/EBITDA(배)',            '52주베타(배)',
                       'PER',                 'PBR',                 'PCR',
       'CASH FLOW 대 부채비율(%)',          '총자본투자효율(%)',           'log_평균총자산',
                  'K2_score',    '최대주주특수관계인_지분율(%)',         '최대주주변경횟수(회)',
               '감사법인변경횟수(회)',               '업력(년)',           '평균근속연수(년)',
                 '직원수증감율(%)',            '기간제비율(%)',           'R&D집중도(%)',
             '수출기업여부(dummy)',              'Target',       '주거래은행_BNK경남은행',
             '주거래은행_BNK부산은행',       '주거래은행_DGB대구은행',       '주거래은행_IBK기업은행',
             '주거래은행_KDB산업은행',       '주거래은행_KEB하나은행',          '주거래은행_NH농협',
              '주거래은행_SC제일은행',          '주거래은행_광주은행',          '주거래은행_국민은행',
                  '주거래은행_수협',          '주거래은행_시티은행',          '주거래은행_신한은행',
                '주거래은행_우리은행',          '주거래은행_전북은행',       '주거래은행_한국수출입은행',
         '주거래은행_한국스탠다드차타드은행',        '주거래은행_한국씨티은행',                     '경기민감_A', '경기민감_AA' ,'경기민감_B', '경기민감_BB', '경기민감_BBB']

# %%
df_train = categorical_data.loc[categorical_data['회계년도'] <= 2019]
df_test = categorical_data.loc[categorical_data['회계년도'] > 2019]

# %%
X_train = df_train.drop(['Target','회사명', '거래소코드', '회계년도'], axis=1)
y_train = df_train['Target']

X_test = df_test.drop(['Target','회사명', '거래소코드', '회계년도'],axis=1)
y_test = df_test['Target']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score, roc_auc_score

# %%
# 모델 함수
def model_basic(X_train, y_train, X_test, y_test):
    models = [
        DecisionTreeClassifier(),
        RandomForestClassifier(),
        XGBClassifier(),
        LGBMClassifier()
    ]

    rdict={'model':[],'accuracy':[],'precision':[],'recall':[],'f1_score':[]}

    
    for clf in models:
        clf = clf.fit(X_train, y_train)
        pred = clf.predict(X_test)
        results = (round(accuracy_score(y_test, pred),2),
                    round(precision_score(y_test, pred),2),
                    round(recall_score(y_test, pred),2),
                    round(f1_score(y_test, pred),2))
        rdict['model'].append(clf); 
        rdict['accuracy'].append(results[0])
        rdict['precision'].append(results[1])
        rdict['recall'].append(results[2])
        rdict['f1_score'].append(results[3])

        # print(results)

    rdf = pd.DataFrame(data=rdict)
    return rdf

# %%
result_df =model_basic(X_train, y_train, X_test, y_test)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 672, number of negative: 6700
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11585
# [LightGBM] [Info] Number of data points in the train set: 7372, number of used features: 69
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.091156 -> initscore=-2.299604
# [LightGBM] [Info] Start training from score -2.299604

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(result_df['model'][1] , scoring = "f1", random_state = 42).fit(X_train, y_train)
eli5.show_weights(perm, top = 80, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0393
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 K2_score
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0193
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 최대주주특수관계인_지분율(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CASH FLOW 대 부채비율(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0143
#
#                     &plusmn; 0.0050
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PER
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#                     &plusmn; 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 log_평균총자산
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 경영자본순이익률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#                     &plusmn; 0.0037
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 이익잉여금비율(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0107
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 매출액순이익률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0102
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EV/EBITDA(배)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0099
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 자기자본순이익률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0095
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 총자본순이익률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0093
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 매출액정상영업이익률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 이자보상배율(이자비용)(배)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 총자본투자효율(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 금융비용부담률(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0061
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 매출액증가율(%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 52주베타(배)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0
