# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df_train=pd.read_excel('./train.xlsx',index_col=0)
df_test = pd.read_excel('./test.xlsx',index_col=0)

# %%
df_train = df_train.reset_index()
df_test = df_test.reset_index()

# %%
df_train = df_train.drop(['index','회사명', '거래소코드', '회계년도','K2_부실판단', '산업위험_경기민감도','주거래은행'],axis=1)
df_test = df_test.drop(['index','회사명', '거래소코드', '회계년도','K2_부실판단', '산업위험_경기민감도','주거래은행'],axis=1)

# %%
df_train.columns
# Out:
# Index(['유동비율(%)', '당좌비율(%)', '비유동비율(%)', '부채비율(%)', '유동부채비율(%)', '차입금의존도(%)',
#        '이익잉여금비율(%)', '순운전자본비율(%)', '비유동장기적합률(%)', '이자보상배율(이자비용)(배)',
#        '외화포지션(배)', '총자본순이익률(%)', '자기자본순이익률(%)', '경영자본순이익률(%)', '매출액순이익률(%)',
#        '총자본정상영업이익률(%)', '자기자본정상영업이익률(%)', '매출액정상영업이익률(%)', '금융비용부담률(%)',
#        '총자산회전율(배)', '매출채권회전률(배)', '당좌자산회전률(배)', '재고자산회전률(배)', '유형자산회전율(배)',
#        '매입채무회전률(배)', '자기자본회전률(배)', '경영자본회전률(배)', '유동자산증가율(%)', '매출액증가율(%)',
#        '정상영업이익증가율(%)', '순이익증가율(%)', 'spread(%)', 'PPI(2015기준)', '실질GDP성장률(%)',
#        'EV/EBITDA(배)', '52주베타(배)', 'PER', 'PBR', 'PCR', 'CASH FLOW 대 부채비율(%)',
#        '총자본투자효율(%)', 'log_평균총자산', 'K2_score', '최대주주특수관계인_지분율(%)',
#        '최대주주변경횟수(회)', '감사법인변경횟수(회)', '업력(년)', '평균근속연수(년)', '직원수증감율(%)',
#        '기간제비율(%)', 'R&D집중도(%)', '수출기업여부(dummy)', 'Target', '주거래은행_0',
#        '주거래은행_1', '주거래은행_2', '주거래은행_3', '주거래은행_4', '산업위험_경기민감도_카테고리화_1안_AA',
#        '산업위험_경기민감도_카테고리화_1안_A_BB', '산업위험_경기민감도_카테고리화_1안_BBB',
#        '산업위험_경기민감도_카테고리화_2안_AA', '산업위험_경기민감도_카테고리화_2안_A_B',
#        '산업위험_경기민감도_카테고리화_2안_BB_BBB', '최대주주변경횟수(회)_카테고리화_1안_0회',
#        '최대주주변경횟수(회)_카테고리화_1안_1~3회', '최대주주변경횟수(회)_카테고리화_1안_4회이상',
#        '최대주주변경횟수(회)_카테고리화_2안_0~1회', '최대주주변경횟수(회)_카테고리화_2안_2~4회',
#        '최대주주변경횟수(회)_카테고리화_2안_5회이상', '감사법인변경횟수(회)_카테고리화_1안_0회',
#        '감사법인변경횟수(회)_카테고리화_1안_1~2회', '감사법인변경횟수(회)_카테고리화_1안_3회이상',
#        '감사법인변경횟수(회)_카테고리화_2안_0회', '감사법인변경횟수(회)_카테고리화_2안_1회이상',
#        '장단기금리차_추세_1안_감소', '장단기금리차_추세_1안_증가', '장단기금리차_추세_2안_-',
#        '장단기금리차_추세_2안_역전', '생산자물가지수_추세_감소', '생산자물가지수_추세_증가', '실질GDP성장_추세_감소',
#        '실질GDP성장_추세_증가', '산업위험_경기민감도_A', '산업위험_경기민감도_AA', '산업위험_경기민감도_B',
#        '산업위험_경기민감도_BB', '산업위험_경기민감도_BBB', 'K2_부실판단_건전판정', 'K2_부실판단_부실가능',
#        'K2_부실판단_판정보류'],
#       dtype='object')

# %%
selected_columns =  ['유동비율(%)', '당좌비율(%)', '비유동비율(%)', '부채비율(%)', '유동부채비율(%)', '차입금의존도(%)',
       '이익잉여금비율(%)', '순운전자본비율(%)', '비유동장기적합률(%)', '이자보상배율(이자비용)(배)',
       '외화포지션(배)', '총자본순이익률(%)', '자기자본순이익률(%)', '경영자본순이익률(%)', '매출액순이익률(%)',
       '총자본정상영업이익률(%)', '자기자본정상영업이익률(%)', '매출액정상영업이익률(%)', '금융비용부담률(%)',
       '총자산회전율(배)', '매출채권회전률(배)', '당좌자산회전률(배)', '재고자산회전률(배)', '유형자산회전율(배)',
       '매입채무회전률(배)', '자기자본회전률(배)', '경영자본회전률(배)', '유동자산증가율(%)', '매출액증가율(%)',
       '정상영업이익증가율(%)', '순이익증가율(%)', 'spread(%)', 'PPI(2015기준)', '실질GDP성장률(%)',
       'EV/EBITDA(배)', '52주베타(배)', 'PER', 'PBR', 'PCR', 'CASH FLOW 대 부채비율(%)',
       '총자본투자효율(%)', 'log_평균총자산', 'K2_score', '최대주주특수관계인_지분율(%)',
       '최대주주변경횟수(회)', '감사법인변경횟수(회)', '업력(년)', '평균근속연수(년)', '직원수증감율(%)',
       '기간제비율(%)', 'R&D집중도(%)', '수출기업여부(dummy)']# 수치형 데이터 컬럼의 인덱스를 넣어주세요.

# StandardScaler 객체를 생성합니다.
scaler = StandardScaler()

# 데이터프레임의 선택된 수치형 데이터 컬럼에 스탠다드 스케일링을 적용하고, 새로운 컬럼에 저장합니다.
df_train_2 = df_train .copy()  # 원본 데이터프레임을 복사합니다.
df_train_2[selected_columns] = scaler.fit_transform(df_train [selected_columns])
df_test_2 = df_test .copy()  # 원본 데이터프레임을 복사합니다.
df_test_2[selected_columns] = scaler.transform(df_test[selected_columns])

# %%
col = selected_columns

# %%
# 1-1 정규성 테스트(샤피로)
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

for j in col:
    a = stats.shapiro(df_train[j])
    p = a.pvalue
    print(j,a)
# Out:
# 유동비율(%) ShapiroResult(statistic=0.22256970405578613, pvalue=0.0)
# 당좌비율(%) ShapiroResult(statistic=0.1959579586982727, pvalue=0.0)
# 비유동비율(%) ShapiroResult(statistic=0.267875611782074, pvalue=0.0)
# 부채비율(%) ShapiroResult(statistic=0.17436522245407104, pvalue=0.0)
# 유동부채비율(%) ShapiroResult(statistic=0.14741921424865723, pvalue=0.0)
# 차입금의존도(%) ShapiroResult(statistic=0.9126735329627991, pvalue=0.0)
# 이익잉여금비율(%) ShapiroResult(statistic=0.03681844472885132, pvalue=0.0)
# 순운전자본비율(%) ShapiroResult(statistic=0.9884647727012634, pvalue=4.696828525879328e-24)
# 비유동장기적합률(%) ShapiroResult(statistic=0.4018476605415344, pvalue=0.0)
# 이자보상배율(이자비용)(배) ShapiroResult(statistic=0.2816169261932373, pvalue=0.0)
# 외화포지션(배) ShapiroResult(statistic=0.007568538188934326, pvalue=0.0)
# 총자본순이익률(%) ShapiroResult(statistic=0.656609833240509, pvalue=0.0)
# 자기자본순이익률(%) ShapiroResult(statistic=0.005697369575500488, pvalue=0.0)
# 경영자본순이익률(%) ShapiroResult(statistic=0.55698561668396, pvalue=0.0)
# 매출액순이익률(%) ShapiroResult(statistic=0.041880249977111816, pvalue=0.0)
# 총자본정상영업이익률(%) ShapiroResult(statistic=0.8873919248580933, pvalue=0.0)
# 자기자본정상영업이익률(%) ShapiroResult(statistic=0.5567629337310791, pvalue=0.0)
# 매출액정상영업이익률(%) ShapiroResult(statistic=0.030490100383758545, pvalue=0.0)
# 금융비용부담률(%) ShapiroResult(statistic=0.32356929779052734, pvalue=0.0)
# 총자산회전율(배) ShapiroResult(statistic=0.8919377326965332, pvalue=0.0)
# 매출채권회전률(배) ShapiroResult(statistic=0.16926658153533936, pvalue=0.0)
# 당좌자산회전률(배) ShapiroResult(statistic=0.8216934204101562, pvalue=0.0)
# 재고자산회전률(배) ShapiroResult(statistic=0.02595067024230957, pvalue=0.0)
# 유형자산회전율(배) ShapiroResult(statistic=0.08303940296173096, pvalue=0.0)
# 매입채무회전률(배) ShapiroResult(statistic=0.009171605110168457, pvalue=0.0)
# 자기자본회전률(배) ShapiroResult(statistic=0.7164531350135803, pvalue=0.0)
# 경영자본회전률(배) ShapiroResult(statistic=0.8904936909675598, pvalue=0.0)
# 유동자산증가율(%) ShapiroResult(statistic=0.48074036836624146, pvalue=0.0)
# 매출액증가율(%) ShapiroResult(statistic=0.2688400149345398, pvalue=0.0)
# 정상영업이익증가율(%) ShapiroResult(statistic=0.0977512001991272, pvalue=0.0)
# 순이익증가율(%) ShapiroResult(statistic=0.0025880932807922363, pvalue=0.0)
# spread(%) ShapiroResult(statistic=0.8641526699066162, pvalue=0.0)
# PPI(2015기준) ShapiroResult(statistic=0.9051598310470581, pvalue=0.0)
# 실질GDP성장률(%) ShapiroResult(statistic=0.9028985500335693, pvalue=0.0)
# EV/EBITDA(배) ShapiroResult(statistic=0.016281068325042725, pvalue=0.0)
# 52주베타(배) ShapiroResult(statistic=0.6188517808914185, pvalue=0.0)
# PER ShapiroResult(statistic=0.01859581470489502, pvalue=0.0)
# PBR ShapiroResult(statistic=0.16979962587356567, pvalue=0.0)
# PCR ShapiroResult(statistic=0.006311237812042236, pvalue=0.0)
# CASH FLOW 대 부채비율(%) ShapiroResult(statistic=0.5088887214660645, pvalue=0.0)
# 총자본투자효율(%) ShapiroResult(statistic=0.7015842199325562, pvalue=0.0)
# log_평균총자산 ShapiroResult(statistic=0.9776985049247742, pvalue=2.0041304407596578e-32)
# K2_score ShapiroResult(statistic=0.5017783641815186, pvalue=0.0)
# 최대주주특수관계인_지분율(%) ShapiroResult(statistic=0.9908251166343689, pvalue=1.8622426586434633e-21)
# 최대주주변경횟수(회) ShapiroResult(statistic=0.9085781574249268, pvalue=0.0)
# 감사법인변경횟수(회) ShapiroResult(statistic=0.7279813289642334, pvalue=0.0)
# 업력(년) ShapiroResult(statistic=0.9748840928077698, pvalue=4.493774854061964e-34)
# 평균근속연수(년) ShapiroResult(statistic=0.8905279636383057, pvalue=0.0)
# 직원수증감율(%) ShapiroResult(statistic=0.12707942724227905, pvalue=0.0)
# 기간제비율(%) ShapiroResult(statistic=0.5530892610549927, pvalue=0.0)
# R&D집중도(%) ShapiroResult(statistic=0.014056146144866943, pvalue=0.0)
# 수출기업여부(dummy) ShapiroResult(statistic=0.41558682918548584, pvalue=0.0)
# c:\Users\kyaa0\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# 1-2 정규성 테스트(K-S)
for j in col:
    a = kstest(df_train[j],'norm')
    p = a.pvalue
    print(j,a)
# Out:
# 유동비율(%) KstestResult(statistic=0.9999991660934341, pvalue=0.0, statistic_location=4.79, statistic_sign=-1)
# 당좌비율(%) KstestResult(statistic=0.999862504869003, pvalue=0.0, statistic_location=4.63, statistic_sign=-1)
# 비유동비율(%) KstestResult(statistic=0.9947805898818394, pvalue=0.0, statistic_location=3.83, statistic_sign=-1)
# 부채비율(%) KstestResult(statistic=0.9943393753300016, pvalue=0.0, statistic_location=3.22, statistic_sign=-1)
# 유동부채비율(%) KstestResult(statistic=0.9882037581886928, pvalue=0.0, statistic_location=3.0, statistic_sign=-1)
# 차입금의존도(%) KstestResult(statistic=0.77396626265777, pvalue=0.0, statistic_location=2.39, statistic_sign=-1)
# 이익잉여금비율(%) KstestResult(statistic=0.7812897412986104, pvalue=0.0, statistic_location=2.995040645919804, statistic_sign=-1)
# 순운전자본비율(%) KstestResult(statistic=0.7485913109299106, pvalue=0.0, statistic_location=2.68, statistic_sign=-1)
# 비유동장기적합률(%) KstestResult(statistic=0.9948445312680987, pvalue=0.0, statistic_location=5.15, statistic_sign=-1)
# 이자보상배율(이자비용)(배) KstestResult(statistic=0.5988972566567624, pvalue=0.0, statistic_location=1.88, statistic_sign=-1)
# 외화포지션(배) KstestResult(statistic=0.5390944260621405, pvalue=0.0, statistic_location=2.149868840613153, statistic_sign=-1)
# 총자본순이익률(%) KstestResult(statistic=0.5143768388030112, pvalue=0.0, statistic_location=1.88, statistic_sign=-1)
# 자기자본순이익률(%) KstestResult(statistic=0.5808280944934161, pvalue=0.0, statistic_location=2.07, statistic_sign=-1)
# 경영자본순이익률(%) KstestResult(statistic=0.5324205235133626, pvalue=0.0, statistic_location=1.88, statistic_sign=-1)
# 매출액순이익률(%) KstestResult(statistic=0.5254579229965974, pvalue=0.0, statistic_location=1.83, statistic_sign=-1)
# 총자본정상영업이익률(%) KstestResult(statistic=0.5936983245703323, pvalue=0.0, statistic_location=1.83, statistic_sign=-1)
# 자기자본정상영업이익률(%) KstestResult(statistic=0.6503927688500097, pvalue=0.0, statistic_location=2.09, statistic_sign=-1)
# 매출액정상영업이익률(%) KstestResult(statistic=0.6119117337241767, pvalue=0.0, statistic_location=1.87, statistic_sign=-1)
# 금융비용부담률(%) KstestResult(statistic=0.18724496668159163, pvalue=9.983309193281123e-227, statistic_location=1.48, statistic_sign=-1)
# 총자산회전율(배) KstestResult(statistic=0.5390247867552719, pvalue=0.0, statistic_location=0.2531896838013927, statistic_sign=-1)
# 매출채권회전률(배) KstestResult(statistic=0.942713405896414, pvalue=0.0, statistic_location=1.96, statistic_sign=-1)
# 당좌자산회전률(배) KstestResult(statistic=0.6770102636366468, pvalue=0.0, statistic_location=0.97, statistic_sign=-1)
# 재고자산회전률(배) KstestResult(statistic=0.8820083956737172, pvalue=0.0, statistic_location=2.07, statistic_sign=-1)
# 유형자산회전율(배) KstestResult(statistic=0.7473873043101649, pvalue=0.0, statistic_location=1.23, statistic_sign=-1)
# 매입채무회전률(배) KstestResult(statistic=0.9421648769787189, pvalue=0.0, statistic_location=2.76, statistic_sign=-1)
# 자기자본회전률(배) KstestResult(statistic=0.5848872853512699, pvalue=0.0, statistic_location=0.41, statistic_sign=-1)
# 경영자본회전률(배) KstestResult(statistic=0.5637062447178793, pvalue=0.0, statistic_location=0.35, statistic_sign=-1)
# 유동자산증가율(%) KstestResult(statistic=0.5024825900256232, pvalue=0.0, statistic_location=2.42, statistic_sign=-1)
# 매출액증가율(%) KstestResult(statistic=0.5198687539045215, pvalue=0.0, statistic_location=2.3, statistic_sign=-1)
# 정상영업이익증가율(%) KstestResult(statistic=0.31858647184679834, pvalue=0.0, statistic_location=2.82, statistic_sign=-1)
# 순이익증가율(%) KstestResult(statistic=0.29360659202575384, pvalue=0.0, statistic_location=-3.28, statistic_sign=1)
# spread(%) KstestResult(statistic=0.4758118020612342, pvalue=0.0, statistic_location=-0.06066801619433004, statistic_sign=-1)
# PPI(2015기준) KstestResult(statistic=1.0, pvalue=0.0, statistic_location=98.18, statistic_sign=-1)
# 실질GDP성장률(%) KstestResult(statistic=0.9860965524865014, pvalue=0.0, statistic_location=2.2, statistic_sign=-1)
# EV/EBITDA(배) KstestResult(statistic=0.7984843400193438, pvalue=0.0, statistic_location=2.59, statistic_sign=-1)
# 52주베타(배) KstestResult(statistic=0.48736626164054, pvalue=0.0, statistic_location=0.3737085546337801, statistic_sign=-1)
# PER KstestResult(statistic=0.6818681185197197, pvalue=0.0, statistic_location=3.0, statistic_sign=-1)
# PBR KstestResult(statistic=0.6570621911331448, pvalue=0.0, statistic_location=0.5449999999999999, statistic_sign=-1)
# PCR KstestResult(statistic=0.6919859001875706, pvalue=0.0, statistic_location=2.59, statistic_sign=-1)
# CASH FLOW 대 부채비율(%) KstestResult(statistic=0.6839240380725501, pvalue=0.0, statistic_location=2.47, statistic_sign=-1)
# 총자본투자효율(%) KstestResult(statistic=0.8789771197586577, pvalue=0.0, statistic_location=2.72, statistic_sign=-1)
# log_평균총자산 KstestResult(statistic=1.0, pvalue=0.0, statistic_location=15.44923963656625, statistic_sign=-1)
# K2_score KstestResult(statistic=0.7013282576287956, pvalue=0.0, statistic_location=2.064831710481466, statistic_sign=-1)
# 최대주주특수관계인_지분율(%) KstestResult(statistic=0.996581100428282, pvalue=0.0, statistic_location=3.33, statistic_sign=-1)
# 최대주주변경횟수(회) KstestResult(statistic=0.6126105173343142, pvalue=0.0, statistic_location=1, statistic_sign=-1)
# 감사법인변경횟수(회) KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0, statistic_sign=-1)
# 업력(년) KstestResult(statistic=0.9195914770600965, pvalue=0.0, statistic_location=2, statistic_sign=-1)
# 평균근속연수(년) KstestResult(statistic=0.9433331674684535, pvalue=0.0, statistic_location=2.0, statistic_sign=-1)
# 직원수증감율(%) KstestResult(statistic=0.483316989475177, pvalue=0.0, statistic_location=2.11, statistic_sign=-1)
# 기간제비율(%) KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# R&D집중도(%) KstestResult(statistic=0.4997286663953331, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)
# 수출기업여부(dummy) KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0, statistic_sign=-1)

# %%
# 부도기업과 정상기업의 피처별 등분산비교 (정규성 가정으로 bartlett)
Bad = df_train_2[df_train_2['Target']== 1] #Existing Customer
Good = df_train_2[df_train_2['Target']== 0] #Attrited Customer

c = []
for i in selected_columns:
    # lresult = stats.levene(close[i], normal[i])
    lresult = stats.bartlett(Bad[i], Good[i])
    c.append([i,lresult[-1]])

c= pd.DataFrame(c)
c.columns=["피처값",'F-test']
c
# Out:
#                     피처값         F-test
# 0               유동비율(%)  1.448536e-169
# 1               당좌비율(%)  1.099259e-182
# 2              비유동비율(%)   0.000000e+00
# 3               부채비율(%)   0.000000e+00
# 4             유동부채비율(%)   0.000000e+00
# 5             차입금의존도(%)   3.009333e-30
# 6            이익잉여금비율(%)   0.000000e+00
# 7            순운전자본비율(%)   4.975465e-35
# 8           비유동장기적합률(%)   0.000000e+00
# 9       이자보상배율(이자비용)(배)   2.492168e-38
# 10             외화포지션(배)   0.000000e+00
# 11           총자본순이익률(%)   0.000000e+00
# 12          자기자본순이익률(%)   0.000000e+00
# 13          경영자본순이익률(%)   0.000000e+00
# 14           매출액순이익률(%)   2.128276e-31
# 15        총자본정상영업이익률(%)  4.333309e-101
# 16       자기자본정상영업이익률(%)   0.000000e+00
# 17        매출액정상영업이익률(%)  1.152344e-121
# 18           금융비용부담률(%)   0.000000e+00
# 19            총자산회전율(배)   1.871403e-09
# 20           매출채권회전률(배)   1.309439e-42
# 21           당좌자산회전률(배)   2.171330e-05
# 22           재고자산회전률(배)   0.000000e+00
# 23           유형자산회전율(배)   0.000000e+00
# 24           매입채무회전률(배)   0.000000e+00
# 25           자기자본회전률(배)  1.476811e-107
# 26           경영자본회전률(배)   1.087769e-04
# 27           유동자산증가율(%)   2.506775e-12
# 28            매출액증가율(%)   5.967072e-04
# 29         정상영업이익증가율(%)   1.467070e-29
# 30            순이익증가율(%)   0.000000e+00
# 31            spread(%)   1.151981e-02
# 32          PPI(2015기준)   3.046039e-02
# 33          실질GDP성장률(%)   3.697124e-01
# 34         EV/EBITDA(배)   2.743295e-51
# 35             52주베타(배)   2.279055e-05
# 36                  PER   1.996387e-73
# 37                  PBR   0.000000e+00
# 38                  PCR   0.000000e+00
# 39  CASH FLOW 대 부채비율(%)   1.679563e-15
# 40           총자본투자효율(%)   0.000000e+00
# 41            log_평균총자산   5.960935e-02
# 42             K2_score   1.249596e-03
# 43     최대주주특수관계인_지분율(%)   2.066765e-09
# 44          최대주주변경횟수(회)   3.251299e-02
# 45          감사법인변경횟수(회)   6.655472e-28
# 46                업력(년)   4.730143e-03
# 47            평균근속연수(년)   2.699270e-01
# 48            직원수증감율(%)   0.000000e+00
# 49             기간제비율(%)   1.472151e-05
# 50            R&D집중도(%)   0.000000e+00
# 51        수출기업여부(dummy)   4.481168e-03

# %%
# F-test 결과 0.05 이상이면 homo 0.05 이하이면 hetero
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
    else:
        c.loc[i,"분산"] = "hetero"
c
# Out:
#                     피처값         F-test      분산 T-test
# 0               유동비율(%)  1.448536e-169  hetero
# 1               당좌비율(%)  1.099259e-182  hetero
# 2              비유동비율(%)   0.000000e+00  hetero
# 3               부채비율(%)   0.000000e+00  hetero
# 4             유동부채비율(%)   0.000000e+00  hetero
# 5             차입금의존도(%)   3.009333e-30  hetero
# 6            이익잉여금비율(%)   0.000000e+00  hetero
# 7            순운전자본비율(%)   4.975465e-35  hetero
# 8           비유동장기적합률(%)   0.000000e+00  hetero
# 9       이자보상배율(이자비용)(배)   2.492168e-38  hetero
# 10             외화포지션(배)   0.000000e+00  hetero
# 11           총자본순이익률(%)   0.000000e+00  hetero
# 12          자기자본순이익률(%)   0.000000e+00  hetero
# 13          경영자본순이익률(%)   0.000000e+00  hetero
# 14           매출액순이익률(%)   2.128276e-31  hetero
# 15        총자본정상영업이익률(%)  4.333309e-101  hetero
# 16       자기자본정상영업이익률(%)   0.000000e+00  hetero
# 17        매출액정상영업이익률(%)  1.152344e-121  hetero
# 18           금융비용부담률(%)   0.000000e+00  hetero
# 19            총자산회전율(배)   1.871403e-09  hetero
# 20           매출채권회전률(배)   1.309439e-42  hetero
# 21           당좌자산회전률(배)   2.171330e-05  hetero
# 22           재고자산회전률(배)   0.000000e+00  hetero
# 23           유형자산회전율(배)   0.000000e+00  hetero
# 24           매입채무회전률(배)   0.000000e+00  hetero
# 25           자기자본회전률(배)  1.476811e-107  hetero
# 26           경영자본회전률(배)   1.087769e-04  hetero
# 27           유동자산증가율(%)   2.506775e-12  hetero
# 28            매출액증가율(%)   5.967072e-04  hetero
# 29         정상영업이익증가율(%)   1.467070e-29  hetero
# 30            순이익증가율(%)   0.000000e+00  hetero
# 31            spread(%)   1.151981e-02  hetero
# 32          PPI(2015기준)   3.046039e-02  hetero
# 33          실질GDP성장률(%)   3.697124e-01    homo
# 34         EV/EBITDA(배)   2.743295e-51  hetero
# 35             52주베타(배)   2.279055e-05  hetero
# 36                  PER   1.996387e-73  hetero
# 37                  PBR   0.000000e+00  hetero
# 38                  PCR   0.000000e+00  hetero
# 39  CASH FLOW 대 부채비율(%)   1.679563e-15  hetero
# 40           총자본투자효율(%)   0.000000e+00  hetero
# 41            log_평균총자산   5.960935e-02    homo
# 42             K2_score   1.249596e-03  hetero
# 43     최대주주특수관계인_지분율(%)   2.066765e-09  hetero
# 44          최대주주변경횟수(회)   3.251299e-02  hetero
# 45          감사법인변경횟수(회)   6.655472e-28  hetero
# 46                업력(년)   4.730143e-03  hetero
# 47            평균근속연수(년)   2.699270e-01    homo
# 48            직원수증감율(%)   0.000000e+00  hetero
# 49             기간제비율(%)   1.472151e-05  hetero
# 50            R&D집중도(%)   0.000000e+00  hetero
# 51        수출기업여부(dummy)   4.481168e-03  hetero

# %%
# homo 인 feature 는 student t-test, hetero이면 Welchs T-Test 진행
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=True)       ## equal_var = True Student T-test
        c.loc[i,"T-test"] = result[-1]
    else:
        c.loc[i,"분산"] = "hetero"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=False)      ## equal_var = False Welchs T-Test
        c.loc[i,"T-test"] = result[-1]
c
# Out:
#                     피처값         F-test      분산    T-test
# 0               유동비율(%)  1.448536e-169  hetero       0.0
# 1               당좌비율(%)  1.099259e-182  hetero       0.0
# 2              비유동비율(%)   0.000000e+00  hetero       0.0
# 3               부채비율(%)   0.000000e+00  hetero       0.0
# 4             유동부채비율(%)   0.000000e+00  hetero       0.0
# 5             차입금의존도(%)   3.009333e-30  hetero       0.0
# 6            이익잉여금비율(%)   0.000000e+00  hetero  0.000734
# 7            순운전자본비율(%)   4.975465e-35  hetero       0.0
# 8           비유동장기적합률(%)   0.000000e+00  hetero       0.0
# 9       이자보상배율(이자비용)(배)   2.492168e-38  hetero       0.0
# 10             외화포지션(배)   0.000000e+00  hetero  0.333811
# 11           총자본순이익률(%)   0.000000e+00  hetero       0.0
# 12          자기자본순이익률(%)   0.000000e+00  hetero  0.108511
# 13          경영자본순이익률(%)   0.000000e+00  hetero       0.0
# 14           매출액순이익률(%)   2.128276e-31  hetero       0.0
# 15        총자본정상영업이익률(%)  4.333309e-101  hetero       0.0
# 16       자기자본정상영업이익률(%)   0.000000e+00  hetero       0.0
# 17        매출액정상영업이익률(%)  1.152344e-121  hetero       0.0
# 18           금융비용부담률(%)   0.000000e+00  hetero       0.0
# 19            총자산회전율(배)   1.871403e-09  hetero       0.0
# 20           매출채권회전률(배)   1.309439e-42  hetero  0.182952
# 21           당좌자산회전률(배)   2.171330e-05  hetero       0.0
# 22           재고자산회전률(배)   0.000000e+00  hetero  0.000834
# 23           유형자산회전율(배)   0.000000e+00  hetero  0.000002
# 24           매입채무회전률(배)   0.000000e+00  hetero  0.029176
# 25           자기자본회전률(배)  1.476811e-107  hetero  0.210488
# 26           경영자본회전률(배)   1.087769e-04  hetero       0.0
# 27           유동자산증가율(%)   2.506775e-12  hetero  0.000263
# 28            매출액증가율(%)   5.967072e-04  hetero   0.00115
# 29         정상영업이익증가율(%)   1.467070e-29  hetero  0.003403
# 30            순이익증가율(%)   0.000000e+00  hetero  0.291825
# 31            spread(%)   1.151981e-02  hetero  0.169553
# 32          PPI(2015기준)   3.046039e-02  hetero  0.808544
# 33          실질GDP성장률(%)   3.697124e-01    homo  0.089048
# 34         EV/EBITDA(배)   2.743295e-51  hetero  0.745933
# 35             52주베타(배)   2.279055e-05  hetero       0.0
# 36                  PER   1.996387e-73  hetero   0.26835
# 37                  PBR   0.000000e+00  hetero       0.0
# 38                  PCR   0.000000e+00  hetero  0.127322
# 39  CASH FLOW 대 부채비율(%)   1.679563e-15  hetero       0.0
# 40           총자본투자효율(%)   0.000000e+00  hetero       0.0
# 41            log_평균총자산   5.960935e-02    homo       0.0
# 42             K2_score   1.249596e-03  hetero       0.0
# 43     최대주주특수관계인_지분율(%)   2.066765e-09  hetero       0.0
# 44          최대주주변경횟수(회)   3.251299e-02  hetero       0.0
# 45          감사법인변경횟수(회)   6.655472e-28  hetero       0.0
# 46                업력(년)   4.730143e-03  hetero  0.005749
# 47            평균근속연수(년)   2.699270e-01    homo       0.0
# 48            직원수증감율(%)   0.000000e+00  hetero  0.933428
# 49             기간제비율(%)   1.472151e-05  hetero  0.003497
# 50            R&D집중도(%)   0.000000e+00  hetero  0.575828
# 51        수출기업여부(dummy)   4.481168e-03  hetero  0.049153

# %%
# 0.05 이상이면 유의미하지 않으므로 0.05 이하인 것만 추출
d = c[c["T-test"]<= 0.05]
d.sort_values('T-test',ascending=False)["피처값"].unique()
# d.sort_values('T-test',ascending=False)["피처값"]
# Out:
# array(['수출기업여부(dummy)', '매입채무회전률(배)', '업력(년)', '기간제비율(%)', '정상영업이익증가율(%)',
#        '매출액증가율(%)', '재고자산회전률(배)', '이익잉여금비율(%)', '유동자산증가율(%)',
#        '유형자산회전율(배)', 'PBR', '이자보상배율(이자비용)(배)', '유동부채비율(%)', '부채비율(%)',
#        '52주베타(배)', '매출액정상영업이익률(%)', '비유동비율(%)', '최대주주변경횟수(회)',
#        '당좌자산회전률(배)', '평균근속연수(년)', '매출액순이익률(%)', '비유동장기적합률(%)',
#        '금융비용부담률(%)', '감사법인변경횟수(회)', '당좌비율(%)', '유동비율(%)', '경영자본회전률(배)',
#        '총자본투자효율(%)', '자기자본정상영업이익률(%)', '총자산회전율(배)', '차입금의존도(%)',
#        '순운전자본비율(%)', 'log_평균총자산', '최대주주특수관계인_지분율(%)',
#        'CASH FLOW 대 부채비율(%)', '경영자본순이익률(%)', 'K2_score', '총자본순이익률(%)',
#        '총자본정상영업이익률(%)'], dtype=object)

# %%
d.sort_values('T-test',ascending=False).dropna()
# Out:
#                     피처값         F-test      분산    T-test
# 51        수출기업여부(dummy)   4.481168e-03  hetero  0.049153
# 24           매입채무회전률(배)   0.000000e+00  hetero  0.029176
# 46                업력(년)   4.730143e-03  hetero  0.005749
# 49             기간제비율(%)   1.472151e-05  hetero  0.003497
# 29         정상영업이익증가율(%)   1.467070e-29  hetero  0.003403
# 28            매출액증가율(%)   5.967072e-04  hetero   0.00115
# 22           재고자산회전률(배)   0.000000e+00  hetero  0.000834
# 6            이익잉여금비율(%)   0.000000e+00  hetero  0.000734
# 27           유동자산증가율(%)   2.506775e-12  hetero  0.000263
# 23           유형자산회전율(배)   0.000000e+00  hetero  0.000002
# 37                  PBR   0.000000e+00  hetero       0.0
# 9       이자보상배율(이자비용)(배)   2.492168e-38  hetero       0.0
# 4             유동부채비율(%)   0.000000e+00  hetero       0.0
# 3               부채비율(%)   0.000000e+00  hetero       0.0
# 35             52주베타(배)   2.279055e-05  hetero       0.0
# 17        매출액정상영업이익률(%)  1.152344e-121  hetero       0.0
# 2              비유동비율(%)   0.000000e+00  hetero       0.0
# 44          최대주주변경횟수(회)   3.251299e-02  hetero       0.0
# 21           당좌자산회전률(배)   2.171330e-05  hetero       0.0
# 47            평균근속연수(년)   2.699270e-01    homo       0.0
# 14           매출액순이익률(%)   2.128276e-31  hetero       0.0
# 8           비유동장기적합률(%)   0.000000e+00  hetero       0.0
# 18           금융비용부담률(%)   0.000000e+00  hetero       0.0
# 45          감사법인변경횟수(회)   6.655472e-28  hetero       0.0
# 1               당좌비율(%)  1.099259e-182  hetero       0.0
# 0               유동비율(%)  1.448536e-169  hetero       0.0
# 26           경영자본회전률(배)   1.087769e-04  hetero       0.0
# 40           총자본투자효율(%)   0.000000e+00  hetero       0.0
# 16       자기자본정상영업이익률(%)   0.000000e+00  hetero       0.0
# 19            총자산회전율(배)   1.871403e-09  hetero       0.0
# 5             차입금의존도(%)   3.009333e-30  hetero       0.0
# 7            순운전자본비율(%)   4.975465e-35  hetero       0.0
# 41            log_평균총자산   5.960935e-02    homo       0.0
# 43     최대주주특수관계인_지분율(%)   2.066765e-09  hetero       0.0
# 39  CASH FLOW 대 부채비율(%)   1.679563e-15  hetero       0.0
# 13          경영자본순이익률(%)   0.000000e+00  hetero       0.0
# 42             K2_score   1.249596e-03  hetero       0.0
# 11           총자본순이익률(%)   0.000000e+00  hetero       0.0
# 15        총자본정상영업이익률(%)  4.333309e-101  hetero       0.0

# %%
X_train = df_train_2.drop(['Target'], axis=1)
y_train = df_train['Target']

X_test = df_test_2.drop(['Target'],axis=1)
y_test = df_test['Target']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import statsmodels.api as sm
import numpy as np
lr_clf = LogisticRegression()

X_train = df_train_2.drop(['Target'], axis=1)
y_train = df_train['Target']

logit = SelectFromModel(LogisticRegression())
logit.fit(X_train, y_train)
logit_support = logit.get_support()
lr_feature = X_train.loc[:,logit_support].columns.tolist()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_feature
# Out:
# ['이익잉여금비율(%)',
#  '순운전자본비율(%)',
#  '총자본순이익률(%)',
#  '매출액순이익률(%)',
#  '총자본정상영업이익률(%)',
#  '자기자본정상영업이익률(%)',
#  '총자산회전율(배)',
#  '유형자산회전율(배)',
#  '자기자본회전률(배)',
#  '경영자본회전률(배)',
#  '52주베타(배)',
#  'log_평균총자산',
#  'K2_score',
#  '주거래은행_2',
#  '주거래은행_3',
#  '산업위험_경기민감도_카테고리화_1안_A_BB',
#  '산업위험_경기민감도_카테고리화_1안_BBB',
#  '산업위험_경기민감도_카테고리화_2안_A_B',
#  '최대주주변경횟수(회)_카테고리화_1안_0회',
#  '최대주주변경횟수(회)_카테고리화_1안_1~3회',
#  '최대주주변경횟수(회)_카테고리화_2안_0~1회',
#  '최대주주변경횟수(회)_카테고리화_2안_2~4회',
#  '감사법인변경횟수(회)_카테고리화_1안_0회',
#  '감사법인변경횟수(회)_카테고리화_2안_0회',
#  '장단기금리차_추세_1안_감소',
#  '장단기금리차_추세_1안_증가',
#  '장단기금리차_추세_2안_-',
#  '장단기금리차_추세_2안_역전',
#  '생산자물가지수_추세_감소',
#  '실질GDP성장_추세_증가',
#  '산업위험_경기민감도_A',
#  '산업위험_경기민감도_BBB',
#  'K2_부실판단_건전판정',
#  'K2_부실판단_부실가능']

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 
                    
    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

vif(X_train[lr_feature])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     VIF Factor                   features
# 0          inf            장단기금리차_추세_2안_역전
# 1          inf             장단기금리차_추세_2안_-
# 2          inf    감사법인변경횟수(회)_카테고리화_1안_0회
# 3          inf             산업위험_경기민감도_BBB
# 4          inf    산업위험_경기민감도_카테고리화_1안_BBB
# 5          inf    감사법인변경횟수(회)_카테고리화_2안_0회
# 6          inf            장단기금리차_추세_1안_감소
# 7          inf            장단기금리차_추세_1안_증가
# 8    12.350194                  총자산회전율(배)
# 9    10.103027                 경영자본회전률(배)
# 10    6.588872  최대주주변경횟수(회)_카테고리화_2안_0~1회
# 11    4.631059  최대주주변경횟수(회)_카테고리화_2안_2~4회
# 12    4.438605    산업위험_경기민감도_카테고리화_2안_A_B
# 13    3.942964    최대주주변경횟수(회)_카테고리화_1안_0회
# 14    3.717813               산업위험_경기민감도_A
# 15    3.641543              총자본정상영업이익률(%)
# 16    3.577192                 자기자본회전률(배)
# 17    3.193443  최대주주변경횟수(회)_카테고리화_1안_1~3회
# 18    2.702504             자기자본정상영업이익률(%)
# 19    2.644202                 총자본순이익률(%)
# 20    2.570789   산업위험_경기민감도_카테고리화_1안_A_BB
# 21    2.491178               K2_부실판단_부실가능
# 22    2.490875               K2_부실판단_건전판정
# 23    2.109130              실질GDP성장_추세_증가
# 24    1.739289              생산자물가지수_추세_감소
# 25    1.703142                 순운전자본비율(%)
# 26    1.381340                  log_평균총자산
# 27    1.362432                   K2_score
# 28    1.160396                    주거래은행_3
# 29    1.160215                    주거래은행_2
# 30    1.061521                 매출액순이익률(%)
# 31    1.054658                 이익잉여금비율(%)
# 32    1.046677                 유형자산회전율(배)
# 33    1.021190                   52주베타(배)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
# 12개 피처로 조정 C 값 조정
lasso = SelectFromModel(LogisticRegression(C=0.01, penalty='l1',solver='liblinear'))
lasso.fit(X_train, y_train)
lasso_support = lasso.get_support()
lasso_feature = X_train.loc[:,lasso_support].columns.tolist()

# %%
col = lasso_feature

# %%
x = df_train[df_train["Target"]==1]
y = df_train[df_train["Target"]==0]

# %%
x[col].describe()
# Out:
#        순운전자본비율(%)  총자본순이익률(%)  자기자본정상영업이익률(%)   총자산회전율(배)    52주베타(배)  \
# count  672.000000  672.000000      672.000000  672.000000  672.000000
# mean    -0.513065  -23.870342      -30.381667    0.621904    0.735328
# std     33.917857   32.225836       62.581073    0.440407    0.915006
# min   -189.960000 -342.510000     -912.330000    0.016773   -3.960429
# 25%    -21.045000  -32.757500      -38.077500    0.325394    0.321155
# 50%      0.865000  -17.900000      -17.685000    0.530075    0.769791
# 75%     21.330000   -6.397500       -0.935000    0.787294    1.175403
# max     87.200000  129.020000       71.120000    2.759721    7.534694
#
#        최대주주특수관계인_지분율(%)       업력(년)   평균근속연수(년)    직원수증감율(%)    기간제비율(%)  \
# count        672.000000  672.000000  672.000000   672.000000  672.000000
# mean          25.275357   11.247024    4.622927     6.793988    3.421607
# std           18.358925    5.703425    2.868254   224.574909    9.903307
# min            0.000000    0.000000    0.000000   -95.090000    0.000000
# 25%           11.530000    7.000000    2.757500   -24.455000    0.000000
# 50%           19.625000   11.000000    4.000000    -6.725000    0.000000
# 75%           36.287500   16.000000    5.700000     8.375000    2.112500
# max           97.550000   27.000000   21.400000  5585.710000  100.000000
#
#         R&D집중도(%)  K2_부실판단_건전판정
# count  672.000000    672.000000
# mean     8.719405      0.241071
# std     30.348777      0.428052
# min      0.000000      0.000000
# 25%      0.347500      0.000000
# 50%      2.360000      0.000000
# 75%      7.040000      0.000000
# max    405.180000      1.000000

# %%
y[col].describe()
# Out:
#         순운전자본비율(%)   총자본순이익률(%)  자기자본정상영업이익률(%)    총자산회전율(배)     52주베타(배)  \
# count  6699.000000  6699.000000     6699.000000  6699.000000  6699.000000
# mean     23.112603     2.207900        6.685677     0.901179     0.981680
# std      24.538863    10.572134       15.252390     0.527630     1.037362
# min    -109.880000  -160.510000     -204.290000     0.000000    -2.679608
# 25%       5.280000    -0.610000        1.285000     0.548791     0.564239
# 50%      23.130000     3.010000        7.060000     0.817653     0.910825
# 75%      40.500000     7.025000       14.490000     1.142594     1.270517
# max      94.820000   167.950000      135.670000     5.424913    22.974989
#
#        최대주주특수관계인_지분율(%)        업력(년)    평균근속연수(년)    직원수증감율(%)     기간제비율(%)  \
# count       6699.000000  6699.000000  6699.000000  6699.000000  6699.000000
# mean          38.714322    10.602777     5.593828     6.067852     4.583972
# std           15.580671     6.195409     2.779793    55.447920     8.782741
# min            2.280000     0.000000     0.000000   -99.340000     0.000000
# 25%           26.940000     5.000000     3.720000    -4.165000     0.000000
# 50%           37.870000    11.000000     5.000000     2.540000     0.680000
# 75%           49.565000    15.000000     6.800000    10.610000     5.420000
# max          100.000000    30.000000    22.583333  2766.670000   100.000000
#
#           R&D집중도(%)  K2_부실판단_건전판정
# count   6699.000000   6699.000000
# mean      10.331151      0.834751
# std      215.420776      0.371432
# min       -0.250000      0.000000
# 25%        0.420000      1.000000
# 50%        1.950000      1.000000
# 75%        5.520000      1.000000
# max    16860.650000      1.000000

# %%
df_test[col]
# Out:
#       순운전자본비율(%)  총자본순이익률(%)  자기자본정상영업이익률(%)  총자산회전율(배)  52주베타(배)  \
# 0          67.74        0.11            1.01   0.332611  1.015400
# 1          56.11        1.60            0.91   0.352194  1.295496
# 2          53.07       -0.19            1.61   0.398596  1.140922
# 3         -28.21       -4.29           14.37   0.136866  1.147440
# 4          17.31        0.60            0.31   0.139949  1.512988
# ...          ...         ...             ...        ...       ...
# 3522       55.66        6.14           11.97   0.249382  0.633780
# 3523       41.97        5.89           12.08   0.273535  0.598912
# 3524       30.09        5.73           -0.63   1.372228  0.920485
# 3525       28.57        1.68           -0.04   1.589409  0.437012
# 3526        4.25        3.01            1.71   1.661754  0.326135
#
#       최대주주특수관계인_지분율(%)  업력(년)  평균근속연수(년)  직원수증감율(%)  기간제비율(%)  R&D집중도(%)  \
# 0                25.84     19       3.90      -1.66      5.91      10.70
# 1                25.84     20       4.20       4.64      2.82       9.83
# 2                25.84     21       4.10       0.00      2.42      11.07
# 3                32.19     18       8.96     -20.00      8.33       0.00
# 4                32.19     19       9.24       4.17      8.00       0.00
# ...                ...    ...        ...        ...       ...        ...
# 3522             43.24      5       3.31       7.76      4.66      11.85
# 3523             43.24      6       3.40       8.47      3.52       9.45
# 3524             34.23     26       7.54     -13.92     51.47       0.00
# 3525             34.23     27       7.61       4.41     52.11       0.00
# 3526             34.23     28       7.80      -2.82     53.62       0.00
#
#       K2_부실판단_건전판정
# 0                1
# 1                1
# 2                1
# 3                0
# 4                0
# ...            ...
# 3522             1
# 3523             1
# 3524             1
# 3525             1
# 3526             1
#
# [3527 rows x 12 columns]

# %%
vif(X_train[lasso_feature])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     VIF Factor                 features
# 0          inf  감사법인변경횟수(회)_카테고리화_2안_0회
# 1          inf  감사법인변경횟수(회)_카테고리화_1안_0회
# 2     6.054886         최대주주특수관계인_지분율(%)
# 3     5.817715                평균근속연수(년)
# 4     5.402843             K2_부실판단_건전판정
# 5     4.382639                    업력(년)
# 6     1.859922               총자본순이익률(%)
# 7     1.788286           자기자본정상영업이익률(%)
# 8     1.550635                  주거래은행_3
# 9     1.460187               순운전자본비율(%)
# 10    1.285731                 기간제비율(%)
# 11    1.228075                log_평균총자산
# 12    1.178293               금융비용부담률(%)
# 13    1.168899                유동부채비율(%)
# 14    1.094668                총자산회전율(배)
# 15    1.032669                R&D집중도(%)
# 16    1.015999                 52주베타(배)
# 17    1.011440                직원수증감율(%)

# %%
j = pd.read_excel("./main_df_dropna_completed.xlsx")
j
# Out:
#        Unnamed: 0       회사명  거래소코드  회계년도  유동비율(%)  당좌비율(%)  비유동비율(%)  부채비율(%)  \
# 0               0  (주)CMG제약  58820  2011   200.97   165.03     66.34    51.41
# 1               1  (주)CMG제약  58820  2012   693.49   649.98     31.65    80.77
# 2               2  (주)CMG제약  58820  2013   694.71   610.74     36.13    14.11
# 3               3  (주)CMG제약  58820  2014   324.58   268.23     60.75    18.50
# 4               4  (주)CMG제약  58820  2015   296.85   235.21     64.65    20.78
# ...           ...       ...    ...   ...      ...      ...       ...      ...
# 10895       17482   흥구석유(주)  24060  2018   329.17   290.09     89.00     6.76
# 10896       17483   흥구석유(주)  24060  2019   485.39   422.76     79.27     8.65
# 10897       17484   흥구석유(주)  24060  2020  1108.08  1013.02     70.39     5.18
# 10898       17485   흥구석유(주)  24060  2021   913.64   818.58     71.15     4.75
# 10899       17486   흥구석유(주)  24060  2022   185.24   115.48    106.47    17.29
#
#        유동부채비율(%)  차입금의존도(%)  ...  최대주주변경횟수(회)  감사법인변경횟수(회)  업력(년)  평균근속연수(년)  \
# 0          42.33       9.08  ...            0            0     10   3.666667
# 1          21.50      30.58  ...            1            0     11   2.900000
# 2          11.23       2.53  ...            1            0     12   3.940000
# 3          17.79       2.66  ...            1            0     13   2.690000
# 4          18.91       0.01  ...            1            1     14   3.310000
# ...          ...        ...  ...          ...          ...    ...        ...
# 10895       5.40       0.00  ...            3            2     24   6.020000
# 10896       6.05       0.00  ...            3            2     25   6.230000
# 10897       3.14       0.50  ...            3            3     26   7.540000
# 10898       3.68       0.44  ...            3            3     27   7.610000
# 10899       5.84       9.74  ...            3            3     28   7.800000
#
#        직원수증감율(%)  기간제비율(%)  R&D집중도(%)  수출기업여부(dummy)    주거래은행  Target
# 0           4.65      0.00       3.32              0  KEB하나은행       0
# 1          -0.74      5.22       2.58              0  KEB하나은행       0
# 2           1.49      0.00      25.21              0  KEB하나은행       0
# 3          20.59      0.00      18.64              0  KEB하나은행       0
# 4          -4.88      5.77      22.22              0  KEB하나은행       0
# ...          ...       ...        ...            ...      ...     ...
# 10895      -9.68     58.33       0.00              0  DGB대구은행       0
# 10896      -5.95     53.16       0.00              0  DGB대구은행       0
# 10897     -13.92     51.47       0.00              0  DGB대구은행       0
# 10898       4.41     52.11       0.00              0  DGB대구은행       0
# 10899      -2.82     53.62       0.00              0  DGB대구은행       0
#
# [10900 rows x 61 columns]

# %%
j[j["당좌비율(%)"]==692.05]
# Out:
#        Unnamed: 0    회사명   거래소코드  회계년도  유동비율(%)  당좌비율(%)  비유동비율(%)  부채비율(%)  \
# 10881       17468  휴젤(주)  145020  2016   760.09   692.05     52.18     7.43
#
#        유동부채비율(%)  차입금의존도(%)  ...  최대주주변경횟수(회)  감사법인변경횟수(회)  업력(년)  평균근속연수(년)  \
# 10881       7.27        0.1  ...            2            1      0       2.29
#
#        직원수증감율(%)  기간제비율(%)  R&D집중도(%)  수출기업여부(dummy)  주거래은행  Target
# 10881      30.95      6.67       3.41              1   신한은행       0
#
# [1 rows x 61 columns]
