# %%
import pandas as pd 
import numpy as np


from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
X = pd.read_excel('./final_data_modeling/min_max_train.xlsx',index_col=0)
y = pd.read_excel('./final_data_modeling/min_max_test.xlsx',index_col=0)

# %%
x_train = X.drop(['Target'],axis=1)
y_train= X['Target']
x_test= y.drop(['Target'],axis=1)
y_test= y['Target']

# %%
x_train
# Out:
#        유동비율(%)   당좌비율(%)  비유동비율(%)   부채비율(%)  유동부채비율(%)  차입금의존도(%)  \
# 0     0.004596  0.003821  0.008597  0.003144   0.002759   0.052568
# 1     0.016135  0.015271  0.004102  0.004939   0.001401   0.177039
# 2     0.016164  0.014345  0.004682  0.000863   0.000732   0.014647
# 3     0.007492  0.006257  0.007873  0.001131   0.001160   0.015400
# 4     0.006843  0.005478  0.008378  0.001271   0.001233   0.000058
# ...        ...       ...       ...       ...        ...        ...
# 7366  0.011698  0.010400  0.012209  0.000881   0.000261   0.037110
# 7367  0.009532  0.007988  0.012054  0.000881   0.000338   0.043884
# 7368  0.004046  0.003388  0.011897  0.000890   0.000836   0.043478
# 7369  0.007600  0.006774  0.011534  0.000413   0.000352   0.000000
# 7370  0.011260  0.009906  0.010273  0.000529   0.000394   0.000000
#
#       이익잉여금비율(%)  순운전자본비율(%)  비유동장기적합률(%)  이자보상배율(이자비용)(배)  ...  \
# 0       0.946197    0.766170     0.016729         0.315769  ...
# ...

# %%
x_test
# Out:
#        유동비율(%)   당좌비율(%)  비유동비율(%)   부채비율(%)  유동부채비율(%)  차입금의존도(%)  \
# 0     0.024946  0.022575  0.003533  0.000480   0.000491   0.001447
# 1     0.021301  0.019236  0.005171  0.000479   0.000484   0.001505
# 2     0.014336  0.012192  0.005479  0.000936   0.000772   0.018237
# 3     0.001329  0.001334  0.073226  0.056785   0.049140   0.005731
# 4     0.020331  0.019224  0.007515  0.051032   0.001364   0.005210
# ...        ...       ...       ...       ...        ...        ...
# 3522  0.026594  0.025644  0.006152  0.001332   0.000425   0.056446
# 3523  0.008052  0.007793  0.006590  0.001442   0.001360   0.055520
# 3524  0.025849  0.023844  0.009122  0.000317   0.000205   0.002895
# 3525  0.021293  0.019252  0.009221  0.000290   0.000240   0.002547
# 3526  0.004228  0.002651  0.013798  0.001057   0.000381   0.056389
#
#       이익잉여금비율(%)  순운전자본비율(%)  비유동장기적합률(%)  이자보상배율(이자비용)(배)  ...  \
# 0       0.950755    0.904909     0.007473         0.315776  ...
# ...

# %%
# x_train= x_train[['유동비율(%)', '당좌비율(%)', '비유동비율(%)', '부채비율(%)', '유동부채비율(%)', '차입금의존도(%)',
#        '이익잉여금비율(%)', '순운전자본비율(%)', '비유동장기적합률(%)', '이자보상배율(이자비용)(배)',
#        '외화포지션(배)', '총자본순이익률(%)', '자기자본순이익률(%)', '경영자본순이익률(%)', '매출액순이익률(%)',
#        '총자본정상영업이익률(%)', '자기자본정상영업이익률(%)', '매출액정상영업이익률(%)', '금융비용부담률(%)',
#        '총자산회전율(배)', '매출채권회전률(배)', '당좌자산회전률(배)', '재고자산회전률(배)', '유형자산회전율(배)',
#        '매입채무회전률(배)', '자기자본회전률(배)', '경영자본회전률(배)', '유동자산증가율(%)', '매출액증가율(%)',
#        '정상영업이익증가율(%)', '순이익증가율(%)', 'spread(%)', 'PPI(2015기준)', '실질GDP성장률(%)',
#        'EV/EBITDA(배)', '52주베타(배)', 'PER', 'PBR', 'PCR', 'CASH FLOW 대 부채비율(%)',
#        '총자본투자효율(%)', 'log_평균총자산', 'K2_score', '최대주주특수관계인_지분율(%)',
#        '최대주주변경횟수(회)', '감사법인변경횟수(회)', '업력(년)', '평균근속연수(년)', '직원수증감율(%)',
#        '기간제비율(%)', 'R&D집중도(%)', '수출기업여부(dummy)', '주거래은행_0', '주거래은행_1',
#        '주거래은행_2', '주거래은행_3', '주거래은행_4']]

# x_test= x_test[['유동비율(%)', '당좌비율(%)', '비유동비율(%)', '부채비율(%)', '유동부채비율(%)', '차입금의존도(%)',
#        '이익잉여금비율(%)', '순운전자본비율(%)', '비유동장기적합률(%)', '이자보상배율(이자비용)(배)',
#        '외화포지션(배)', '총자본순이익률(%)', '자기자본순이익률(%)', '경영자본순이익률(%)', '매출액순이익률(%)',
#        '총자본정상영업이익률(%)', '자기자본정상영업이익률(%)', '매출액정상영업이익률(%)', '금융비용부담률(%)',
#        '총자산회전율(배)', '매출채권회전률(배)', '당좌자산회전률(배)', '재고자산회전률(배)', '유형자산회전율(배)',
#        '매입채무회전률(배)', '자기자본회전률(배)', '경영자본회전률(배)', '유동자산증가율(%)', '매출액증가율(%)',
#        '정상영업이익증가율(%)', '순이익증가율(%)', 'spread(%)', 'PPI(2015기준)', '실질GDP성장률(%)',
#        'EV/EBITDA(배)', '52주베타(배)', 'PER', 'PBR', 'PCR', 'CASH FLOW 대 부채비율(%)',
#        '총자본투자효율(%)', 'log_평균총자산', 'K2_score', '최대주주특수관계인_지분율(%)',
#        '최대주주변경횟수(회)', '감사법인변경횟수(회)', '업력(년)', '평균근속연수(년)', '직원수증감율(%)',
#        '기간제비율(%)', 'R&D집중도(%)', '수출기업여부(dummy)', '주거래은행_0', '주거래은행_1',
#        '주거래은행_2', '주거래은행_3', '주거래은행_4']]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
feature_selected = ['차입금의존도(%)',
 '순운전자본비율(%)',
 '총자본순이익률(%)',
 '자기자본정상영업이익률(%)',
 '금융비용부담률(%)',
 '총자산회전율(배)',
 'log_평균총자산',
 'K2_score',
 '최대주주특수관계인_지분율(%)',
 '감사법인변경횟수(회)']

# %%
################################################
##         LASSO, SMOTE, Logistic            ##
###############################################
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.inspection import permutation_importance

models = [
        DecisionTreeClassifier(),
        LogisticRegression(),
        RandomForestClassifier(),
        XGBClassifier(),
        LGBMClassifier(),
        CatBoostClassifier()
        ]

params = [[0.25, 0.5],
        ['auto',0.3,0.5]]

rdict_smote={'models':[],'params':[],'accuracy':[],'precision':[],'recall':[],'f1_score':[], 'cv_score':[]}
rdict_bdsmt={'models':[],'params':[],'accuracy':[],'precision':[],'recall':[],'f1_score':[], 'cv_score':[]}
selected_features_dict = {}
for clf in models:
        for strategy in params[1]:
                        x_test_feature_selected = x_test[feature_selected]

                        #####################################################################################

                        ## OverSampling_1
                        sm = SMOTE(random_state=0, sampling_strategy=strategy)
                        x_train_smote, y_train_smote = sm.fit_resample(x_train[feature_selected], y_train)

                        clf_1 = clf.fit(x_train_smote, y_train_smote)
                        pred_1 = clf.predict(x_test_feature_selected)

                        cv_scores_1 = cross_val_score(clf_1, x_train_smote, y_train_smote, cv=5, scoring='recall')

                        # 성능 지표 계산
                        accuracy_1 = accuracy_score(y_test, pred_1)
                        precision_1 = precision_score(y_test, pred_1)
                        recall_1 = recall_score(y_test, pred_1)
                        f1_1 = f1_score(y_test, pred_1)

                        rdict_smote['models'].append((clf)); 
                        rdict_smote['params'].append((C,strategy)); 
                        rdict_smote['accuracy'].append(round(accuracy_1,2))
                        rdict_smote['precision'].append(round(precision_1,2))
                        rdict_smote['recall'].append(round(recall_1,2))
                        rdict_smote['f1_score'].append(round(f1_1,2))
                        rdict_smote['cv_score'].append(round(cv_scores_1.mean(), 2))

                        # Permutation Importance 계산
                        print(f'Model : {clf_1} & C : {C} & sampling_strategy : {strategy} --- SMOTE \n')
                        perm_importance = permutation_importance(clf_1, x_test_feature_selected, y_test, n_repeats=30, random_state=0)

                        # 각 피처의 Permutation Importance 값 출력
                        for i, feature_name in enumerate(x_test_feature_selected.columns):
                                print(f"{feature_name}: {perm_importance.importances_mean[i]}")

                        

                        print("____________________________________________________________________")
                        ######################################################################################

                        ## OverSampling_2
                        bdsmt = BorderlineSMOTE(random_state=0, sampling_strategy=strategy)
                        x_train_border, y_train_border = bdsmt.fit_resample(x_train[feature_selected], y_train)

                        clf_2 = clf.fit(x_train_border, y_train_border)
                        pred_2 = clf.predict(x_test_feature_selected)

                        cv_scores_2 = cross_val_score(clf_2, x_train_border, y_train_border, cv=5, scoring='recall')

                        # 성능 지표 계산
                        accuracy_2 = accuracy_score(y_test, pred_2)
                        precision_2 = precision_score(y_test, pred_2)
                        recall_2 = recall_score(y_test, pred_2)
                        f1_2 = f1_score(y_test, pred_2)
                        
                        rdict_bdsmt['models'].append((clf_2)); 
                        rdict_bdsmt['params'].append((C,strategy)); 
                        rdict_bdsmt['accuracy'].append(round(accuracy_2,2))
                        rdict_bdsmt['precision'].append(round(precision_2,2))
                        rdict_bdsmt['recall'].append(round(recall_2,2))
                        rdict_bdsmt['f1_score'].append(round(f1_2,2))
                        rdict_bdsmt['cv_score'].append(round(cv_scores_2.mean(), 2))
                        
                        print(f'Model : {clf_2} & C : {C} & sampling_strategy : {strategy} --- bdsmt \n')
                        # Permutation Importance 계산
                        perm_importance = permutation_importance(clf_2, x_test_feature_selected, y_test, n_repeats=30, random_state=0)

                        # 각 피처의 Permutation Importance 값 출력
                        for i, feature_name in enumerate(x_test_feature_selected.columns):
                                print(f"{feature_name}: {perm_importance.importances_mean[i]}")

smote_result2 = pd.DataFrame(data=rdict_smote)
bdsmt_result2 = pd.DataFrame(data=rdict_bdsmt)
# Out:
# Model : DecisionTreeClassifier() & C : 0.25 & sampling_strategy : auto --- SMOTE
#
# 차입금의존도(%): 0.010509403648048437
# 순운전자본비율(%): -0.0036858519988658524
# 총자본순이익률(%): 0.03398544561005581
# 자기자본정상영업이익률(%): 0.012153860693696287
# 금융비용부담률(%): 0.01767318778943393
# 총자산회전율(배): 0.005283054531707828
# log_평균총자산: -0.002570645496644893
# K2_score: -0.0020697476609015776
# 최대주주특수관계인_지분율(%): 0.011076457801720103
# 감사법인변경횟수(회): 0.0021453548813912147
# ____________________________________________________________________
# Model : DecisionTreeClassifier() & C : 0.25 & sampling_strategy : auto --- bdsmt
#
# 차입금의존도(%): 0.022285228239296854
# 순운전자본비율(%): -0.002551743691522527
# 총자본순이익률(%): 0.023721765428598433
# 자기자본정상영업이익률(%): 0.02733201020697477
# 금융비용부담률(%): 0.003317266798979298
# 총자산회전율(배): 0.008950004725451282
# log_평균총자산: 0.005103487383045091
# K2_score: 0.028069180606747946
# 최대주주특수관계인_지분율(%): 0.005623287023910787
# 감사법인변경횟수(회): 0.005679992439277952
# ...

# %%
smote_result2
# Out:
#                                                models        params  accuracy  \
# 0                            DecisionTreeClassifier()  (0.25, auto)      0.81
# 1                            DecisionTreeClassifier()   (0.25, 0.3)      0.85
# 2                            DecisionTreeClassifier()   (0.25, 0.5)      0.83
# 3                                LogisticRegression()  (0.25, auto)      0.77
# 4                                LogisticRegression()   (0.25, 0.3)      0.88
# 5                                LogisticRegression()   (0.25, 0.5)      0.84
# 6   (DecisionTreeClassifier(max_features='sqrt', r...  (0.25, auto)      0.86
# 7   (DecisionTreeClassifier(max_features='sqrt', r...   (0.25, 0.3)      0.90
# 8   (DecisionTreeClassifier(max_features='sqrt', r...   (0.25, 0.5)      0.88
# 9   XGBClassifier(base_score=None, booster=None, c...  (0.25, auto)      0.87
# 10  XGBClassifier(base_score=None, booster=None, c...   (0.25, 0.3)      0.90
# ...

# %%
ada_result2
# Out:
#                                                models        params  accuracy  \
# 0                            DecisionTreeClassifier()  (0.25, auto)      0.80
# 1                            DecisionTreeClassifier()   (0.25, 0.3)      0.78
# 2                            DecisionTreeClassifier()   (0.25, 0.5)      0.83
# 3                            DecisionTreeClassifier()   (0.5, auto)      0.84
# 4                            DecisionTreeClassifier()    (0.5, 0.3)      0.84
# 5                            DecisionTreeClassifier()    (0.5, 0.5)      0.85
# 6                                LogisticRegression()  (0.25, auto)      0.69
# 7                                LogisticRegression()   (0.25, 0.3)      0.83
# 8                                LogisticRegression()   (0.25, 0.5)      0.75
# 9                                LogisticRegression()   (0.5, auto)      0.75
# 10                               LogisticRegression()    (0.5, 0.3)      0.85
# ...

# %%
# smote_result
# Out:
#                                                models       params  accuracy  \
# 0                            DecisionTreeClassifier()  (0.5, auto)      0.70
# 1                            DecisionTreeClassifier()  (0.5, 0.33)      0.85
# 2                                LogisticRegression()  (0.5, auto)      0.72
# 3                                LogisticRegression()  (0.5, 0.33)      0.84
# 4   (DecisionTreeClassifier(max_features='sqrt', r...  (0.5, auto)      0.87
# 5   (DecisionTreeClassifier(max_features='sqrt', r...  (0.5, 0.33)      0.90
# 6   XGBClassifier(base_score=None, booster=None, c...  (0.5, auto)      0.91
# 7   XGBClassifier(base_score=None, booster=None, c...  (0.5, 0.33)      0.91
# 8                                    LGBMClassifier()  (0.5, auto)      0.89
# 9                                    LGBMClassifier()  (0.5, 0.33)      0.91
# 10  <catboost.core.CatBoostClassifier object at 0x...  (0.5, auto)      0.89
# ...

# %%
# ada_result
# Out:
#                                                models       params  accuracy  \
# 0                            DecisionTreeClassifier()  (0.5, auto)      0.84
# 1                            DecisionTreeClassifier()  (0.5, 0.33)      0.84
# 2                                LogisticRegression()  (0.5, auto)      0.75
# 3                                LogisticRegression()  (0.5, 0.33)      0.84
# 4   (DecisionTreeClassifier(max_features='sqrt', r...  (0.5, auto)      0.88
# 5   (DecisionTreeClassifier(max_features='sqrt', r...  (0.5, 0.33)      0.91
# 6   XGBClassifier(base_score=None, booster=None, c...  (0.5, auto)      0.90
# 7   XGBClassifier(base_score=None, booster=None, c...  (0.5, 0.33)      0.91
# 8                                    LGBMClassifier()  (0.5, auto)      0.89
# 9                                    LGBMClassifier()  (0.5, 0.33)      0.91
# 10  <catboost.core.CatBoostClassifier object at 0x...  (0.5, auto)      0.90
# ...

# %% [markdown]
# ### Lasso: c = 0.03, sampling_strategy = 0.33, Model : XGboost Classifier

# %%
# Lasso Feature  Select
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

lasso = SelectFromModel(LogisticRegression(C=C,penalty='l1',solver='saga'))
lasso.fit(x_train_scaled, y_train)

lasso_support = lasso.get_support()
feature_selected = x_train_scaled.loc[:,lasso_support].columns.tolist()

# %% [markdown]
# ### Lasso Feature Select 한 변수 10개로 Try

# %%
# Lasso feature로 해볼것

# %%
a = {'차입금의존도(%)': -0.0055476798034212686,
'순운전자본비율(%)': -0.0046025895473018165,
'이자보상배율(이자비용)(배)': 0.003950477270579281,
'총자본순이익률(%)': -0.0028258198657972375,
'총자본정상영업이익률(%)': 0.018542670825063744,
'매출액정상영업이익률(%)': 0.008524714110197467,
'총자산회전율(배)': -0.0003024288819582684,
'당좌자산회전률(배)': -0.0011908137227105672,
'자기자본회전률(배)': 0.009857291371325901,
'spread(%)': 0.000595406861355204,
'PPI(2015기준)': 0.001398733579056736,
'실질GDP성장률(%)': 0.0010774028919761276,
'52주베타(배)': 0.004498629619128566,
'log_평균총자산': 0.0065589263774689915,
'최대주주특수관계인_지분율(%)': -0.0006993667895284439,
'최대주주변경횟수(회)': 0.0016066534354030196,
'감사법인변경횟수(회)': 0.00303373972214341,
'업력(년)': 0.012645307626878311,
'평균근속연수(년)': 0.0006048577639164073,
'수출기업여부(dummy)': -0.00040638881013140465,
'주거래은행_0': 0.0005292505434268402,
'주거래은행_1': -2.835270768362097e-05,
'주거래은행_2': 5.6705415367123516e-05,
'주거래은행_3': 0.0018618278045552754}

pd.DataFrame(index = a.keys(), data = a.values()).sort_values(0, ascending = False)
# Out:
#                          0
# 총자본정상영업이익률(%)     0.018543
# 업력(년)             0.012645
# 자기자본회전률(배)        0.009857
# 매출액정상영업이익률(%)     0.008525
# log_평균총자산         0.006559
# 52주베타(배)          0.004499
# 이자보상배율(이자비용)(배)   0.003950
# 감사법인변경횟수(회)       0.003034
# 주거래은행_3           0.001862
# 최대주주변경횟수(회)       0.001607
# PPI(2015기준)       0.001399
# 실질GDP성장률(%)       0.001077
# 평균근속연수(년)         0.000605
# spread(%)         0.000595
# 주거래은행_0           0.000529
# 주거래은행_2           0.000057
# 주거래은행_1          -0.000028
# 총자산회전율(배)        -0.000302
# 수출기업여부(dummy)    -0.000406
# 최대주주특수관계인_지분율(%) -0.000699
# 당좌자산회전률(배)       -0.001191
# 총자본순이익률(%)       -0.002826
# 순운전자본비율(%)       -0.004603
# 차입금의존도(%)        -0.005548
